# %%
import gacos

# %%
path = "/Volumes/Data/GeoData/YNG/Sentinel1/Hype3/descending_roi"

ds = gacos.HyPe3Dataset(path)
# Out:
# /Users/fancy/miniconda3/envs/geo/lib/python3.11/site-packages/faninsar/datasets/base.py:1072: UserWarning: Duplicate pairs found in dataset, keeping only the first occurrence
# Deduplicate pairs:
# 	S1AA_20191115T232700_20200314T232657_VVP120_INT40_G_ueF_F25B
#   warnings.warn(

# %%
submitter = gacos.Submitter(
    ds,
    email="fanchengyan2020@126.com"
)
    
submitter.post_requests()
# Out:
# >>> succeed post: {'N': 39.16527884776772, 'W': 98.34602960014247, 'S': 38.52041942953548, 'E': 99.41788862899489, 'H': 0, 'M': 0, 'date': '20151112\n20151206\n20151230\n20160123\n20160216\n20160311\n20160404\n20160428\n20160522\n20160615\n20160709\n20160802\n20160826\n20160919\n20161007\n20161031\n20161124\n20161218\n20170111', 'type': '2', 'email': 'fanchengyan2020@126.com'}
# >>> succeed post: {'N': 39.16527884776772, 'W': 98.34602960014247, 'S': 38.52041942953548, 'E': 99.41788862899489, 'H': 0, 'M': 0, 'date': '20170204\n20170222\n20170318\n20170330\n20170411\n20170423\n20170505\n20170517\n20170529\n20170610\n20170622\n20170704\n20170716\n20170728\n20170809\n20170821\n20170902\n20170914\n20171008', 'type': '2', 'email': 'fanchengyan2020@126.com'}
# ...
